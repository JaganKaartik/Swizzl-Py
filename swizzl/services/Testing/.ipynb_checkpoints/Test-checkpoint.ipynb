# %%
from bs4 import BeautifulSoup
import requests

# %%
def linkText(link):
    url = "{}".format(link)
    r = requests.get(url)
    soup = BeautifulSoup(r.content,"lxml")
    article_text = ''
    mylink = soup.find('div').findAll('p')
    for i in mylink:
        article_text += ''.join(i.findAll(text = True))
    return article_text

# %%
def YahooFetch():
    url = "https://news.yahoo.com/rss/"
    url = requests.get(url)
    soup = BeautifulSoup(url.text,'xml')
    
    try:
        # Fetch All Required items

        titles = soup.findAll('title')
        links = soup.findAll('link')
        pubDates = soup.findAll('pubDate')

    except Exception as e :
        # Return Empty if titles, links, descriptions, pubdates not found
       
        print(e)
        return "Error"

    # We don't want the first elements as these are just metadata
    
    titles.pop(0)
    titles.pop(0)
    links.pop(0)
    links.pop(0)
    pubDates.pop(0)

    #Dictionary to hold crawled information

    FeedDict = {}
    temp = []
    temptext = []
    try:
        for i in titles:
            temp.append(i.get_text())
            FeedDict['title'] = temp
        temp = []
        for i in links:
            temp.append(i.get_text())
            temptext.append(linkText(i.get_text()))
            FeedDict['link'] = temp
            FeedDict['linktext'] = temptext
        temp = []
        for i in pubDates:
            temp.append(i.get_text())
            FeedDict['pubdate'] = temp
        
        print("Success")
    except Exception as e :
        print(e)
        return "Error"
    
    return FeedDict

# %%
import time
start_time = time.time()
FeedDict = YahooFetch()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Success
# --- 120.22221279144287 seconds ---

# %%
# print(FeedDict['title'][0])
# print(FeedDict['link'][0])
# print(FeedDict['linktext'][0])
# print(FeedDict['pubdate'][0])

# %%
docs = []
for i in range(0,len(FeedDict['title'])):
    docs.append(FeedDict['title'][i])

# %%
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation)
lemma = WordNetLemmatizer()
def clean(doc):
    stop_free = " ".join([i for i in doc.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

doc_clean = [clean(doc).split() for doc in docs]

# %%
doc_clean
# Out:
# [['39you',
#   'embarrassed',
#   'yourself39',
#   'kellyanne',
#   'conway',
#   'blast',
#   'cnn39s',
#   'wolf',
#   'blitzer',
#   'playing',
#   'george',
#   'conway',
#   'clip'],
#  ['virginia',
#   'police',
#   'say',
#   'wanted',
#   'marine',
#   'deserter',
#   'sought',
#   'family'],
#  ['man',
#   'caught',
#   'houston',
#   'airport',
#   '35',
#   'pound',
#   'liquid',
#   'cocaine',
#   'shampoo',
#   'bottle'],
#  ['temper', 'flare', 'rebuilding', 'notredame', 'spire'],
#  ['fox',
#   'regular',
#   'claim',
#   'george',
#   'soros',
#   '‘controls',
#   'large',
#   'part’',
#   'state',
#   'department'],
#  ['russia',
#   'blame',
#   'fatal',
#   'plane',
#   'crash',
#   'pilot',
#   'including',
#   'one',
#   'lied',
#   'get',
#   'license'],
#  ['supreme',
#   'court',
#   'justice',
#   'brett',
#   'kavanaugh',
#   'get',
#   'hero39s',
#   'welcome',
#   'conservative',
#   'federalist',
#   'society'],
#  ['pirate',
#   'attacked',
#   'italian',
#   'ship',
#   'coast',
#   'mexico',
#   '—',
#   'latest',
#   'sign',
#   'growing',
#   'criminal',
#   'industry'],
#  ['dnc', 'announces', '10', 'candidate', 'atlanta', 'democratic', 'debate'],
#  ['trump', 'impeachment', '39has', 'hard', 'family39'],
#  ['american',
#   'war',
#   'veteran',
#   'spent',
#   'several',
#   'day',
#   'ice',
#   'detention',
#   'receives',
#   '190k',
#   'settlement'],
#  ['latest', 'officer', 'say', 'miranda', 'failure', 'mistake'],
#  ['vietnam', 'jail', 'music', 'teacher', '39undermining39', 'state'],
#  ['rep',
#   'steve',
#   'king',
#   'falsely',
#   'id',
#   'george',
#   'soros’',
#   'son',
#   'whistleblower'],
#  ['american',
#   'teacher39s',
#   'death',
#   'dr',
#   'investigated',
#   'thursday',
#   'murder'],
#  ['history', 'modern', 'american', 'architecture'],
#  ['39he',
#   'doesn39t',
#   'seem',
#   'like',
#   'kind',
#   'kid',
#   'this39',
#   'classmate',
#   'neighbor',
#   'surprised',
#   'suspected',
#   'santa',
#   'clarita',
#   'shooter39s',
#   'identity'],
#  ['one',
#   'jamal',
#   'khashoggi’s',
#   'close',
#   'friend',
#   'said',
#   'twitter',
#   '39only',
#   'free',
#   'platform39',
#   'many',
#   'saudi',
#   'also',
#   'may',
#   'led',
#   'khashoggi’s',
#   'brutal',
#   'murder'],
#  ['fox',
#   'news39',
#   'bret',
#   'baier',
#   'suggests',
#   'trump',
#   'broke',
#   'law',
#   '39real',
#   'time39',
#   'tweeted',
#   'attack',
#   'yovanovitch'],
#  ['three',
#   'judge',
#   'suspended',
#   'following',
#   'drunken',
#   'shooting',
#   'car',
#   'park',
#   'failing',
#   'get',
#   'strip',
#   'club'],
#  ['suspect', '‘potomac', 'river', 'rapist’', 'cold', 'case', 'arrested'],
#  ['iraq', '39will', 'never', 'same39', 'protest', 'top', 'shiite', 'cleric'],
#  ['moving',
#   'university',
#   'vienna',
#   'soros',
#   'vow',
#   'defend',
#   'academic',
#   'freedom',
#   'orban'],
#  ['hyundai',
#   'santa',
#   'cruz',
#   'small',
#   'pickup',
#   'start',
#   'production',
#   '2021'],
#  ['u',
#   'marine',
#   'corp',
#   'making',
#   'big',
#   'change',
#   'thanks',
#   'threat',
#   'russia',
#   'china'],
#  ['39anonymous39',
#   'key',
#   'excerpt',
#   'inside',
#   'trump',
#   'white',
#   'house',
#   'putin',
#   'hillary'],
#  ['scientist', 'fighting', 'one', 'hottest', 'place', 'earth'],
#  ['trump',
#   'lash',
#   'former',
#   'adviser',
#   'roger',
#   'stone',
#   'convicted',
#   '7',
#   'count'],
#  ['bloomberg',
#   'responded',
#   '‘kill',
#   'it’',
#   'employee',
#   'disclosed',
#   'pregnancy',
#   '1997',
#   'lawsuit',
#   'alleges'],
#  ['police', 'indication', 'restaurant', 'staff', 'heard', 'racial', 'comment'],
#  ['federal',
#   'judge',
#   'rule',
#   'usborn',
#   '39isis',
#   'bride39',
#   'american',
#   'citizen'],
#  ['50',
#   'year',
#   'it39s',
#   'past',
#   'time',
#   'bring',
#   'human',
#   'lgbtq',
#   'character',
#   'america39s',
#   'sesame',
#   'street'],
#  ['39come', 'back', 'tomorrow39', 'battling', 'asylum', 'south', 'africa'],
#  ['view', 'photo', '2020', 'morgan', 'plus', '4'],
#  ['bolivia',
#   'interim',
#   'leader',
#   'recognises',
#   'guaido',
#   'legitimate',
#   'venezuelan',
#   'leader',
#   'balance',
#   'shift'],
#  ['saugus', 'school', 'shooting', 'california', 'know'],
#  ['russia',
#   'land',
#   'force',
#   'former',
#   'u',
#   'air',
#   'base',
#   'northern',
#   'syria'],
#  ['rather', 'retiring', 'storied', 'b52', 'getting', 'upgraded', 'here39s'],
#  ['georgia',
#   'inmate',
#   'executed',
#   '1994',
#   'convenience',
#   'store',
#   'killing',
#   'lastminute',
#   'dna',
#   'test',
#   'denied'],
#  ['new',
#   'seal',
#   'navy39s',
#   'next',
#   'aircraft',
#   'carrier',
#   'contains',
#   'hint',
#   'big',
#   'change',
#   'coming',
#   'naval',
#   'aviation'],
#  ['n', 'korea', 'call', 'biden', '‘rabid', 'dog’', 'insulting', 'dignity'],
#  ['black',
#   'south',
#   'carolina',
#   'leader',
#   'distance',
#   'buttigieg',
#   'campaign’s',
#   '‘douglass',
#   'plan’'],
#  ['french', 'tourist', 'killed', 'taking', 'selfie', 'thai', 'waterfall'],
#  ['mass', 'shooting', 'day', '2019'],
#  ['offduty',
#   'officer',
#   'first',
#   'responder',
#   'california',
#   'high',
#   'school',
#   'shooting',
#   '—',
#   'dropping',
#   'family',
#   'member',
#   'school'],
#  ['see', 'photo', '2020', 'nissan', 'titan'],
#  ['pelosi',
#   'trump',
#   'make',
#   'nixon',
#   'watergate',
#   '‘look',
#   'almost',
#   'small’'],
#  ['trump',
#   'release',
#   '2nd',
#   'zelensky',
#   'call',
#   'transcript',
#   'second',
#   'yovanovitch',
#   'appears',
#   'public',
#   'impeachment',
#   'hearing'],
#  ['chicago',
#   'teacher',
#   'vote',
#   'agreement',
#   'guarantee',
#   '16',
#   'raise',
#   '35m',
#   'reduce',
#   'class'],
#  ['taliban',
#   'say',
#   'prisoner',
#   'swap',
#   'promised',
#   'kabul',
#   'fails',
#   'happen']]
